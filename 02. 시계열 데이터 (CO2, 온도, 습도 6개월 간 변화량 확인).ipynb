# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import math

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df1 = pd.read_csv('1동 데이터.csv', index=False)
df2 = pd.read_csv('2동 데이터.csv', index=False)
df3 = pd.read_csv('3동 데이터.csv', index=False)
df4 = pd.read_csv('16동 데이터.csv', index=False)
